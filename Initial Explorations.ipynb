# %%
import requests
import json

# %%
U
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-89bccbe6d21e> in <module>()
# ----> 1 U
#
# NameError: name 'U' is not defined

# %%
URL = 'https://www.alphavantage.co/query?'

PARAMS = {'function':'TIME_SERIES_WEEKLY', 'symbol':'MSFT','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}

# %%
response = requests.get(URL,PARAMS)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{\n    "Meta Data": {\n        "1. Information": "Weekly Prices (open, high, low, close) and Volumes",\n        "2. Symbol": "MSFT",\n        "3. Last Refreshed": "2019-01-04 13:27:29",\n        "4. Time Zone": "US/Eastern"\n    },\n    "Weekly Time Series": {\n        "2019-01-04": {\n            "1. open": "101.2900",\n            "2. high": "102.5100",\n            "3. low": "97.2000",\n            "4. close": "102.2350",\n            "5. volume": "135850094"\n        },\n        "2018-12-28": {\n            "1. open": "97.6800",\n            "2. high": "102.4100",\n            "3. low": "93.9600",\n            "4. close": "100.3900",\n            "5. volume": "183237806"\n        },\n        "2018-12-21": {\n            "1. open": "105.4100",\n            "2. high": "106.8800",\n            "3. low": "97.4600",\n            "4. close": "98.2300",\n            "5. volume": "356050950"\n        },\n        "2018-12-14": {\n            "1. open": "104.8000",\n            "2. high"
# ...

# %%
x =response.json()

# %%
x.keys()
# Out:
# dict_keys(['Meta Data', 'Weekly Time Series'])

# %%
import pandas as pd

# %%
df = pd.DataFrame(x['Weekly Time Series'])

# %%
df.head()
# Out:
#           2019-01-04 2018-12-28 2018-12-21 2018-12-14 2018-12-07 2018-11-30  \
# 1. open     101.2900    97.6800   105.4100   104.8000   113.0000   104.7900
# 2. high     102.5100   102.4100   106.8800   111.2700   113.4200   111.3300
# 3. low       97.2000    93.9600    97.4600   103.8900   104.3000   104.5800
# 4. close    102.2350   100.3900    98.2300   106.0300   104.8200   110.8900
# 5. volume  135850094  183237806  356050950  197742990  174082124  170037931
#
#           2018-11-23 2018-11-16 2018-11-09 2018-11-02    ...     1998-03-13  \
# 1. open     108.2700   109.4200   106.3700   108.1050    ...        82.5000
# 2. high     108.5600   109.9600   112.2400   108.7000    ...        83.0000
# 3. low       99.3528   103.9100   105.9000   100.1100    ...        79.5000
# 4. close    103.0700   108.2900   109.5700   106.1600    ...        82.3700
# 5. volume  150780076  180498817  147847424  242639657    ...       55001400
#
# ...

# %%
df.transpose().head()['1. open']
# Out:
# 2019-01-04    101.2900
# 2018-12-28     97.6800
# 2018-12-21    105.4100
# 2018-12-14    104.8000
# 2018-12-07    113.0000
# Name: 1. open, dtype: object

# %%
df.transpose().tail()
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 1998-02-06  151.7500  158.7500  150.5000  158.1300  42349700
# 1998-01-30  139.8800  150.1300  138.4500  149.1900  46856000
# 1998-01-23  134.1300  139.8800  134.0000  138.2500  46621800
# 1998-01-16  124.6200  135.3800  124.3700  135.2500  40459900
# 1998-01-09  131.2500  133.6300  125.8700  127.0000  46857300

# %%
msft_df = df.transpose()

# %%
msft_df
# Out:
#              1. open   2. high    3. low  4. close  5. volume
# 2019-01-04  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12  111.6600  113.0800  104.2000  109.5700  228861873
# 2018-10-05  114.7500  116.1800  110.6400  112.1300  120208912
# ...

# %%
PARAMS = {'function':'TIME_SERIES_WEEKLY', 'symbol':'NKE','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}

# %%
response = requests.get(URL,PARAMS)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{\n    "Meta Data": {\n        "1. Information": "Weekly Prices (open, high, low, close) and Volumes",\n        "2. Symbol": "NKE",\n        "3. Last Refreshed": "2019-01-04 13:27:27",\n        "4. Time Zone": "US/Eastern"\n    },\n    "Weekly Time Series": {\n        "2019-01-04": {\n            "1. open": "73.9800",\n            "2. high": "75.1200",\n            "3. low": "71.2100",\n            "4. close": "74.7500",\n            "5. volume": "23949085"\n        },\n        "2018-12-28": {\n            "1. open": "71.4000",\n            "2. high": "74.4600",\n            "3. low": "68.0800",\n            "4. close": "73.3400",\n            "5. volume": "33772585"\n        },\n        "2018-12-21": {\n            "1. open": "71.3700",\n            "2. high": "74.2900",\n            "3. low": "66.5300",\n            "4. close": "72.3700",\n            "5. volume": "69583503"\n        },\n        "2018-12-14": {\n            "1. open": "73.1000",\n            "2. high": "75.2800",
# ...

# %%
n = response.json()

# %%
nike_df = df = pd.DataFrame(n['Weekly Time Series'])

# %%
nike_df
# Out:
#           2019-01-04 2018-12-28 2018-12-21 2018-12-14 2018-12-07 2018-11-30  \
# 1. open      73.9800    71.4000    71.3700    73.1000    77.1000    72.3400
# 2. high      75.1200    74.4600    74.2900    75.2800    79.0000    75.4800
# 3. low       71.2100    68.0800    66.5300    70.6100    72.8700    71.3000
# 4. close     74.7500    73.3400    72.3700    72.5300    73.3400    75.1200
# 5. volume   23949085   33772585   69583503   36656249   34837049   31017859
#
#           2018-11-23 2018-11-16 2018-11-09 2018-11-02    ...     1998-03-13  \
# 1. open      74.6900    76.3500    76.4900    73.2600    ...        46.7500
# 2. high      74.7500    77.4900    78.2300    78.5900    ...        47.6300
# 3. low       69.5200    72.8900    75.5250    71.3900    ...        44.7500
# 4. close     71.4900    74.7400    76.3600    76.5800    ...        44.8100
# 5. volume   25707323   33696138   29134168   41212603    ...        5589000
#
# ...

# %%
nike_df.transpose()
# Out:
#             1. open  2. high   3. low 4. close 5. volume
# 2019-01-04  73.9800  75.1200  71.2100  74.7500  23949085
# 2018-12-28  71.4000  74.4600  68.0800  73.3400  33772585
# 2018-12-21  71.3700  74.2900  66.5300  72.3700  69583503
# 2018-12-14  73.1000  75.2800  70.6100  72.5300  36656249
# 2018-12-07  77.1000  79.0000  72.8700  73.3400  34837049
# 2018-11-30  72.3400  75.4800  71.3000  75.1200  31017859
# 2018-11-23  74.6900  74.7500  69.5200  71.4900  25707323
# 2018-11-16  76.3500  77.4900  72.8900  74.7400  33696138
# 2018-11-09  76.4900  78.2300  75.5250  76.3600  29134168
# 2018-11-02  73.2600  78.5900  71.3900  76.5800  41212603
# 2018-10-26  74.6500  75.2100  70.6900  72.0700  42819364
# 2018-10-19  75.7700  77.8000  74.1400  74.2100  35273556
# 2018-10-12  80.0400  81.4900  73.9000  75.9100  50606095
# 2018-10-05  85.1000  85.8500  79.4300  80.1200  42550204
# 2018-09-28  85.1600  85.2700  81.9500  84.7200  49180255
# ...

# %%
nike_df = nike_df.transpose()

# %%
nike_df
# Out:
#             1. open  2. high   3. low 4. close 5. volume
# 2019-01-04  73.9800  75.1200  71.2100  74.7500  23949085
# 2018-12-28  71.4000  74.4600  68.0800  73.3400  33772585
# 2018-12-21  71.3700  74.2900  66.5300  72.3700  69583503
# 2018-12-14  73.1000  75.2800  70.6100  72.5300  36656249
# 2018-12-07  77.1000  79.0000  72.8700  73.3400  34837049
# 2018-11-30  72.3400  75.4800  71.3000  75.1200  31017859
# 2018-11-23  74.6900  74.7500  69.5200  71.4900  25707323
# 2018-11-16  76.3500  77.4900  72.8900  74.7400  33696138
# 2018-11-09  76.4900  78.2300  75.5250  76.3600  29134168
# 2018-11-02  73.2600  78.5900  71.3900  76.5800  41212603
# 2018-10-26  74.6500  75.2100  70.6900  72.0700  42819364
# 2018-10-19  75.7700  77.8000  74.1400  74.2100  35273556
# 2018-10-12  80.0400  81.4900  73.9000  75.9100  50606095
# 2018-10-05  85.1000  85.8500  79.4300  80.1200  42550204
# 2018-09-28  85.1600  85.2700  81.9500  84.7200  49180255
# ...

# %%
pd.concat(msft_df,nike_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-f55c27e5ed42> in <module>()
# ----> 1 pd.concat(msft_df,nike_df)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     239             raise TypeError('first argument must be an iterable of pandas '
# ...

# %%
frames = [msft_df, nike_df]

# %%
pd.concat(frames)
# Out:
#              1. open   2. high    3. low  4. close  5. volume
# 2019-01-04  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12  111.6600  113.0800  104.2000  109.5700  228861873
# 2018-10-05  114.7500  116.1800  110.6400  112.1300  120208912
# ...

# %%
idx = 0

new_col = 'MSFT'

msft_df.insert(loc=idx, column='Entity', value=new_col)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
PARAMS = {'function':'SMA', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}

# %%
MSFT_sma_response = requests.get(URL,PARAMS)

# %%
MSFT_sma_response.status_code
# Out:
# 200

# %%
MSFT_sma_data = MSFT_sma_response.json()

# %%
MSFT_sma_data
# Out:
# {'Meta Data': {'1: Symbol': 'MSFT',
#   '2: Indicator': 'Simple Moving Average (SMA)',
#   '3: Last Refreshed': '2019-01-04 13:27:31',
#   '4: Interval': 'weekly',
#   '5: Time Period': 2,
#   '6: Series Type': 'open',
#   '7: Time Zone': 'US/Eastern'},
#  'Technical Analysis: SMA': {'2019-01-04 13:27:31': {'SMA': '99.4850'},
#   '2018-12-28': {'SMA': '101.5450'},
#   '2018-12-21': {'SMA': '105.1050'},
#   '2018-12-14': {'SMA': '108.9000'},
#   '2018-12-07': {'SMA': '108.8950'},
#   '2018-11-30': {'SMA': '106.5300'},
#   '2018-11-23': {'SMA': '108.8450'},
#   '2018-11-16': {'SMA': '107.8950'},
#   '2018-11-09': {'SMA': '107.2375'},
#   '2018-11-02': {'SMA': '108.7125'},
#   '2018-10-26': {'SMA': '109.1150'},
#   '2018-10-19': {'SMA': '110.2850'},
#   '2018-10-12': {'SMA': '113.2050'},
#   '2018-10-05': {'SMA': '113.8900'},
#   '2018-09-28': {'SMA': '113.3600'},
#   '2018-09-21': {'SMA': '111.2650'},
#   '2018-09-14': {'SMA': '109.8450'},
#   '2018-09-07': {'SMA': '110.0600'},
# ...

# %%
len(MSFT_sma_data[ 'Technical Analysis: SMA'])
# Out:
# 1095

# %%
MSFT_sma_data.keys()
# Out:
# dict_keys(['Meta Data', 'Technical Analysis: SMA'])

# %%
MSFT_sma_df = pd.DataFrame(MSFT_sma_data['Technical Analysis: SMA'])

# %%
MSFT_sma_df.transpose()
# Out:
#                           SMA
# 2019-01-04 13:27:31   99.4850
# 2018-12-28           101.5450
# 2018-12-21           105.1050
# 2018-12-14           108.9000
# 2018-12-07           108.8950
# 2018-11-30           106.5300
# 2018-11-23           108.8450
# 2018-11-16           107.8950
# 2018-11-09           107.2375
# 2018-11-02           108.7125
# 2018-10-26           109.1150
# 2018-10-19           110.2850
# 2018-10-12           113.2050
# 2018-10-05           113.8900
# 2018-09-28           113.3600
# 2018-09-21           111.2650
# 2018-09-14           109.8450
# 2018-09-07           110.0600
# 2018-08-31           108.3900
# 2018-08-24           108.3750
# 2018-08-17           108.6800
# 2018-08-10           107.6550
# 2018-08-03           106.7450
# 2018-07-27           105.8500
# 2018-07-20           103.5226
# 2018-07-13            99.8726
# 2018-07-06            99.0500
# 2018-06-29           100.0050
# 2018-06-22           100.6900
# 2018-06-15           101.3150
# ...

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
MSFT_sma_df = MSFT_sma_df.transpose()

# %%
MSFT_sma_df
# Out:
#                           SMA
# 2019-01-04 13:27:31   99.4850
# 2018-12-28           101.5450
# 2018-12-21           105.1050
# 2018-12-14           108.9000
# 2018-12-07           108.8950
# 2018-11-30           106.5300
# 2018-11-23           108.8450
# 2018-11-16           107.8950
# 2018-11-09           107.2375
# 2018-11-02           108.7125
# 2018-10-26           109.1150
# 2018-10-19           110.2850
# 2018-10-12           113.2050
# 2018-10-05           113.8900
# 2018-09-28           113.3600
# 2018-09-21           111.2650
# 2018-09-14           109.8450
# 2018-09-07           110.0600
# 2018-08-31           108.3900
# 2018-08-24           108.3750
# 2018-08-17           108.6800
# 2018-08-10           107.6550
# 2018-08-03           106.7450
# 2018-07-27           105.8500
# 2018-07-20           103.5226
# 2018-07-13            99.8726
# 2018-07-06            99.0500
# 2018-06-29           100.0050
# 2018-06-22           100.6900
# 2018-06-15           101.3150
# ...

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
PARAMS = {'function':'SMA', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}

# %%
idx = 6

msft_df.insert(loc=idx, column='SMA', value=MSFT_sma_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume       SMA
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094       NaN
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806  101.5450
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950  105.1050
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990  108.9000
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124  108.8950
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931  106.5300
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076  108.8450
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817  107.8950
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424  107.2375
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657  108.7125
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718  109.1150
# ...

# %%
len(msft_df)
# Out:
# 1096

# %%
msft_df[897:898]
# Out:
#            Entity  1. open  2. high   3. low 4. close  5. volume      SMA
# 2001-10-26   MSFT  57.9000  63.6300  57.4700  62.2000  185808800  56.9000

# %%
msft_df['SMA'][0] = 69.5594

# %%
msft_df['SMA']
# Out:
# 2019-01-04     69.5594
# 2018-12-28    101.5450
# 2018-12-21    105.1050
# 2018-12-14    108.9000
# 2018-12-07    108.8950
# 2018-11-30    106.5300
# 2018-11-23    108.8450
# 2018-11-16    107.8950
# 2018-11-09    107.2375
# 2018-11-02    108.7125
# 2018-10-26    109.1150
# 2018-10-19    110.2850
# 2018-10-12    113.2050
# 2018-10-05    113.8900
# 2018-09-28    113.3600
# 2018-09-21    111.2650
# 2018-09-14    109.8450
# 2018-09-07    110.0600
# 2018-08-31    108.3900
# 2018-08-24    108.3750
# 2018-08-17    108.6800
# 2018-08-10    107.6550
# 2018-08-03    106.7450
# 2018-07-27    105.8500
# 2018-07-20    103.5226
# 2018-07-13     99.8726
# 2018-07-06     99.0500
# 2018-06-29    100.0050
# 2018-06-22    100.6900
# 2018-06-15    101.3150
#                 ...
# 1998-07-31    115.6550
# 1998-07-24    116.1550
# 1998-07-17    110.4950
# 1998-07-10    106.1850
# 1998-07-02    100.1250
# 1998-06-26     89.7200
# 1998-06-19     85.1550
# 1998-06-12     84.7450
# 1998-06-05     84.5900
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(0,897,1)
plt.plot(x, MSFT_sma_data)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-44634314d189> in <module>()
#       1 import numpy as np
#       2 x = np.linspace(0,897,1)
# ----> 3 plt.plot(x, MSFT_sma_data)
#       4
#       5 plt.show()
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
MSFT_sma_data

# %%
len(msft_df)
# Out:
# 1096

# %%
msft_df[890:900]
# Out:
#            Entity  1. open  2. high   3. low 4. close  5. volume      SMA
# 2001-12-14   MSFT  67.5200  68.4500  65.9300  67.4400  118407000  65.6750
# 2001-12-07   MSFT  63.8300  69.0000  63.8000  67.8300  135410800  64.4100
# 2001-11-30   MSFT  64.9900  65.7100  62.7300  64.2100  144803900  65.6200
# 2001-11-23   MSFT  66.2500  67.8000  63.4800  64.7100   94233300  65.4750
# 2001-11-16   MSFT  64.7000  68.3400  63.6500  65.7500  171854500  63.2800
# 2001-11-09   MSFT  61.8600  66.0600  61.7500  65.2100  158077000  61.9800
# 2001-11-02   MSFT  62.1000  63.0200  58.1000  61.4000  185128100  60.0000
# 2001-10-26   MSFT  57.9000  63.6300  57.4700  62.2000  185808800  56.9000
# 2001-10-19   MSFT  55.9000  59.3000  55.5000  57.9000  188942100  56.3500
# 2001-10-12   MSFT  56.8000  58.6500  53.0000  56.3800  196741100  53.8700

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume       SMA
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094   69.5594
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806  101.5450
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950  105.1050
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990  108.9000
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124  108.8950
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931  106.5300
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076  108.8450
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817  107.8950
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424  107.2375
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657  108.7125
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718  109.1150
# ...

# %%
MSFT_sma_data
# Out:
# {'Meta Data': {'1: Symbol': 'MSFT',
#   '2: Indicator': 'Simple Moving Average (SMA)',
#   '3: Last Refreshed': '2019-01-04 13:27:31',
#   '4: Interval': 'weekly',
#   '5: Time Period': 2,
#   '6: Series Type': 'open',
#   '7: Time Zone': 'US/Eastern'},
#  'Technical Analysis: SMA': {'2019-01-04 13:27:31': {'SMA': '99.4850'},
#   '2018-12-28': {'SMA': '101.5450'},
#   '2018-12-21': {'SMA': '105.1050'},
#   '2018-12-14': {'SMA': '108.9000'},
#   '2018-12-07': {'SMA': '108.8950'},
#   '2018-11-30': {'SMA': '106.5300'},
#   '2018-11-23': {'SMA': '108.8450'},
#   '2018-11-16': {'SMA': '107.8950'},
#   '2018-11-09': {'SMA': '107.2375'},
#   '2018-11-02': {'SMA': '108.7125'},
#   '2018-10-26': {'SMA': '109.1150'},
#   '2018-10-19': {'SMA': '110.2850'},
#   '2018-10-12': {'SMA': '113.2050'},
#   '2018-10-05': {'SMA': '113.8900'},
#   '2018-09-28': {'SMA': '113.3600'},
#   '2018-09-21': {'SMA': '111.2650'},
#   '2018-09-14': {'SMA': '109.8450'},
#   '2018-09-07': {'SMA': '110.0600'},
# ...

# %%
msft_df['SMA'][0] = 101.5450

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume       SMA
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094   101.545
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806  101.5450
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950  105.1050
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990  108.9000
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124  108.8950
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931  106.5300
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076  108.8450
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817  107.8950
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424  107.2375
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657  108.7125
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718  109.1150
# ...

# %%
PARAMS = {'function':'EMA', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}

ema_response = requests.get(URL,PARAMS)

# %%
ema_response.status_code
# Out:
# 200

# %%
ema_response.json()
# Out:
# {'Meta Data': {'1: Symbol': 'MSFT',
#   '2: Indicator': 'Exponential Moving Average (EMA)',
#   '3: Last Refreshed': '2019-01-04 13:27:40',
#   '4: Interval': 'weekly',
#   '5: Time Period': 2,
#   '6: Series Type': 'open',
#   '7: Time Zone': 'US/Eastern'},
#  'Technical Analysis: EMA': {'2019-01-04 13:27:40': {'EMA': '100.9954'},
#   '2018-12-28': {'EMA': '100.4061'},
#   '2018-12-21': {'EMA': '105.8582'},
#   '2018-12-14': {'EMA': '106.7547'},
#   '2018-12-07': {'EMA': '110.6641'},
#   '2018-11-30': {'EMA': '105.9923'},
#   '2018-11-23': {'EMA': '108.3969'},
#   '2018-11-16': {'EMA': '108.6507'},
#   '2018-11-09': {'EMA': '107.1121'},
#   '2018-11-02': {'EMA': '108.5963'},
#   '2018-10-26': {'EMA': '109.5788'},
#   '2018-10-19': {'EMA': '110.0963'},
#   '2018-10-12': {'EMA': '112.4689'},
#   '2018-10-05': {'EMA': '114.0868'},
#   '2018-09-28': {'EMA': '112.7604'},
#   '2018-09-21': {'EMA': '112.2213'},
#   '2018-09-14': {'EMA': '109.2839'},
#   '2018-09-07': {'EMA': '110.1718'},
# ...

# %%
e = ema_response.json()

# %%
ema_data = pd.DataFrame(e['Technical Analysis: EMA'])

# %%
ema_data.transpose()
# Out:
#                           EMA
# 2019-01-04 13:27:40  100.9954
# 2018-12-28           100.4061
# 2018-12-21           105.8582
# 2018-12-14           106.7547
# 2018-12-07           110.6641
# 2018-11-30           105.9923
# 2018-11-23           108.3969
# 2018-11-16           108.6507
# 2018-11-09           107.1121
# 2018-11-02           108.5963
# 2018-10-26           109.5788
# 2018-10-19           110.0963
# 2018-10-12           112.4689
# 2018-10-05           114.0868
# 2018-09-28           112.7604
# 2018-09-21           112.2213
# 2018-09-14           109.2839
# 2018-09-07           110.1718
# 2018-08-31           108.8155
# 2018-08-24           107.9066
# 2018-08-17           108.6999
# 2018-08-10           107.6196
# 2018-08-03           106.6187
# 2018-07-27           105.4762
# 2018-07-20           103.8287
# 2018-07-13           100.6862
# 2018-07-06            98.7683
# 2018-06-29           100.1048
# 2018-06-22           100.3144
# 2018-06-15           100.9232
# ...

# %%
ema_df = ema_data.transpose()

# %%
ema_df
# Out:
#                           EMA
# 2019-01-04 13:27:40  100.9954
# 2018-12-28           100.4061
# 2018-12-21           105.8582
# 2018-12-14           106.7547
# 2018-12-07           110.6641
# 2018-11-30           105.9923
# 2018-11-23           108.3969
# 2018-11-16           108.6507
# 2018-11-09           107.1121
# 2018-11-02           108.5963
# 2018-10-26           109.5788
# 2018-10-19           110.0963
# 2018-10-12           112.4689
# 2018-10-05           114.0868
# 2018-09-28           112.7604
# 2018-09-21           112.2213
# 2018-09-14           109.2839
# 2018-09-07           110.1718
# 2018-08-31           108.8155
# 2018-08-24           107.9066
# 2018-08-17           108.6999
# 2018-08-10           107.6196
# 2018-08-03           106.6187
# 2018-07-27           105.4762
# 2018-07-20           103.8287
# 2018-07-13           100.6862
# 2018-07-06            98.7683
# 2018-06-29           100.1048
# 2018-06-22           100.3144
# 2018-06-15           100.9232
# ...

# %%
idx = 7


msft_df.insert(loc=idx, column='EMA', value=ema_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
msft_df['EMA'][0] = 100.9954

# %%
msft_df.head()
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
#
#                  SMA       EMA
# 2019-01-04   101.545   100.995
# 2018-12-28  101.5450  100.4061
# 2018-12-21  105.1050  105.8582
# 2018-12-14  108.9000  106.7547
# 2018-12-07  108.8950  110.6641

# %%
PARAMS = {'function':'MACD', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}

macd_response = requests.get(URL,PARAMS)

# %%
macd_response.status_code
# Out:
# 200

# %%
macd_response.json()
# Out:
# {'Meta Data': {'1: Symbol': 'MSFT',
#   '2: Indicator': 'Moving Average Convergence/Divergence (MACD)',
#   '3: Last Refreshed': '2019-01-04 13:27:45',
#   '4: Interval': 'weekly',
#   '5.1: Fast Period': 12,
#   '5.2: Slow Period': 26,
#   '5.3: Signal Period': 9,
#   '6: Series Type': 'open',
#   '7: Time Zone': 'US/Eastern'},
#  'Technical Analysis: MACD': {'2019-01-04 13:27:45': {'MACD': '0.2448',
#    'MACD_Hist': '-1.6971',
#    'MACD_Signal': '1.9419'},
#   '2018-12-28': {'MACD': '0.6957',
#    'MACD_Hist': '-1.6705',
#    'MACD_Signal': '2.3661'},
#   '2018-12-21': {'MACD': '1.6286',
#    'MACD_Hist': '-1.1551',
#    'MACD_Signal': '2.7838'},
#   '2018-12-14': {'MACD': '2.0087',
#    'MACD_Hist': '-1.0638',
#    'MACD_Signal': '3.0725'},
#   '2018-12-07': {'MACD': '2.5267',
#    'MACD_Hist': '-0.8118',
#    'MACD_Signal': '3.3385'},
#   '2018-11-30': {'MACD': '2.3162',
#    'MACD_Hist': '-1.2253',
#    'MACD_Signal': '3.5415'},
#   '2018-11-23': {'MACD': '2.8497',
# ...

# %%
m = macd_response.json()

# %%
macd_data = pd.DataFrame(m['Technical Analysis: MACD'])

# %%
macd_data.transpose()
# Out:
#                         MACD MACD_Hist MACD_Signal
# 2019-01-04 13:27:45   0.2448   -1.6971      1.9419
# 2018-12-28            0.6957   -1.6705      2.3661
# 2018-12-21            1.6286   -1.1551      2.7838
# 2018-12-14            2.0087   -1.0638      3.0725
# 2018-12-07            2.5267   -0.8118      3.3385
# 2018-11-30            2.3162   -1.2253      3.5415
# 2018-11-23            2.8497   -0.9981      3.8478
# 2018-11-16            3.1349   -0.9624      4.0973
# 2018-11-09            3.3363   -1.0016      4.3379
# 2018-11-02            3.8553   -0.7330      4.5883
# 2018-10-26            4.2850   -0.4865      4.7715
# 2018-10-19            4.6474   -0.2457      4.8932
# 2018-10-12            5.0842    0.1296      4.9546
# 2018-10-05            5.2877    0.3655      4.9222
# 2018-09-28            5.1559    0.3251      4.8308
# 2018-09-21            5.0878    0.3383      4.7496
# 2018-09-14            4.8597    0.1947      4.6650
# ...

# %%
macd_df = macd_data.transpose()

# %%
macd_hist_df = macd_df.drop(['MACD', 'MACD_Signal'], axis = 1)

# %%
macd_hist_df
# Out:
#                     MACD_Hist
# 2019-01-04 13:27:45   -1.6971
# 2018-12-28            -1.6705
# 2018-12-21            -1.1551
# 2018-12-14            -1.0638
# 2018-12-07            -0.8118
# 2018-11-30            -1.2253
# 2018-11-23            -0.9981
# 2018-11-16            -0.9624
# 2018-11-09            -1.0016
# 2018-11-02            -0.7330
# 2018-10-26            -0.4865
# 2018-10-19            -0.2457
# 2018-10-12             0.1296
# 2018-10-05             0.3655
# 2018-09-28             0.3251
# 2018-09-21             0.3383
# 2018-09-14             0.1947
# 2018-09-07             0.3754
# 2018-08-31             0.3604
# 2018-08-24             0.4015
# 2018-08-17             0.5483
# 2018-08-10             0.4973
# 2018-08-03             0.4275
# 2018-07-27             0.3158
# 2018-07-20             0.1441
# 2018-07-13            -0.1067
# 2018-07-06            -0.1715
# 2018-06-29             0.0439
# 2018-06-22             0.1335
# 2018-06-15             0.2075
# ...

# %%
macd_signal_df = macd_df.drop(['MACD', 'MACD_Hist'], axis = 1)

# %%
macd_signal_df
# Out:
#                     MACD_Signal
# 2019-01-04 13:27:45      1.9419
# 2018-12-28               2.3661
# 2018-12-21               2.7838
# 2018-12-14               3.0725
# 2018-12-07               3.3385
# 2018-11-30               3.5415
# 2018-11-23               3.8478
# 2018-11-16               4.0973
# 2018-11-09               4.3379
# 2018-11-02               4.5883
# 2018-10-26               4.7715
# 2018-10-19               4.8932
# 2018-10-12               4.9546
# 2018-10-05               4.9222
# 2018-09-28               4.8308
# 2018-09-21               4.7496
# 2018-09-14               4.6650
# 2018-09-07               4.6163
# 2018-08-31               4.5225
# 2018-08-24               4.4324
# 2018-08-17               4.3320
# 2018-08-10               4.1949
# 2018-08-03               4.0706
# 2018-07-27               3.9637
# 2018-07-20               3.8848
# 2018-07-13               3.8487
# 2018-07-06               3.8754
# 2018-06-29               3.9183
# ...

# %%
macd_df = macd_df.drop(['MACD_Hist', 'MACD_Signal'], axis = 1)

# %%
macd_df
# Out:
#                         MACD
# 2019-01-04 13:27:45   0.2448
# 2018-12-28            0.6957
# 2018-12-21            1.6286
# 2018-12-14            2.0087
# 2018-12-07            2.5267
# 2018-11-30            2.3162
# 2018-11-23            2.8497
# 2018-11-16            3.1349
# 2018-11-09            3.3363
# 2018-11-02            3.8553
# 2018-10-26            4.2850
# 2018-10-19            4.6474
# 2018-10-12            5.0842
# 2018-10-05            5.2877
# 2018-09-28            5.1559
# 2018-09-21            5.0878
# 2018-09-14            4.8597
# 2018-09-07            4.9917
# 2018-08-31            4.8829
# 2018-08-24            4.8339
# 2018-08-17            4.8802
# 2018-08-10            4.6922
# 2018-08-03            4.4981
# 2018-07-27            4.2795
# 2018-07-20            4.0289
# 2018-07-13            3.7421
# 2018-07-06            3.7039
# 2018-06-29            3.9622
# 2018-06-22            4.0408
# 2018-06-15            4.0814
# ...                      ...
# ...

# %%
idx = 8

msft_df.insert(loc=idx, column='MACD', value=macd_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
idx = 9

msft_df.insert(loc=idx, column='MACD_Hist', value=macd_hist_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
idx = 10

msft_df.insert(loc=idx, column='MACD_Signal', value=macd_signal_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
PARAMS = {'function':'STOCH', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}

stoch_response = requests.get(URL,PARAMS)

# %%
stoch_response.status_code
# Out:
# 200

# %%
stoch_response.json()
# Out:
# {'Meta Data': {'1: Symbol': 'MSFT',
#   '2: Indicator': 'Stochastic (STOCH)',
#   '3: Last Refreshed': '2019-01-04 16:00:01',
#   '4: Interval': 'weekly',
#   '5.1: FastK Period': 5,
#   '5.2: SlowK Period': 3,
#   '5.3: SlowK MA Type': 0,
#   '5.4: SlowD Period': 3,
#   '5.5: SlowD MA Type': 0,
#   '6: Time Zone': 'US/Eastern Time'},
#  'Technical Analysis: STOCH': {'2019-01-04 16:00:01': {'SlowK': '26.2742',
#    'SlowD': '28.3679'},
#   '2018-12-28': {'SlowK': '28.4444', 'SlowD': '39.1494'},
#   '2018-12-21': {'SlowK': '30.3853', 'SlowD': '47.1384'},
#   '2018-12-14': {'SlowK': '58.6186', 'SlowD': '57.6549'},
#   '2018-12-07': {'SlowK': '52.4112', 'SlowD': '56.9173'},
#   '2018-11-30': {'SlowK': '61.9349', 'SlowD': '59.2271'},
#   '2018-11-23': {'SlowK': '56.4059', 'SlowD': '54.9589'},
#   '2018-11-16': {'SlowK': '59.3405', 'SlowD': '48.5661'},
#   '2018-11-09': {'SlowK': '49.1303', 'SlowD': '41.9925'},
#   '2018-11-02': {'SlowK': '37.2274', 'SlowD': '40.8159'},
# ...

# %%
st = stoch_response.json()

# %%
stoch_data = pd.DataFrame(st['Technical Analysis: STOCH'])

# %%
stoch_data.transpose()
# Out:
#                        SlowD    SlowK
# 2019-01-04 16:00:01  28.3679  26.2742
# 2018-12-28           39.1494  28.4444
# 2018-12-21           47.1384  30.3853
# 2018-12-14           57.6549  58.6186
# 2018-12-07           56.9173  52.4112
# 2018-11-30           59.2271  61.9349
# 2018-11-23           54.9589  56.4059
# 2018-11-16           48.5661  59.3405
# 2018-11-09           41.9925  49.1303
# 2018-11-02           40.8159  37.2274
# 2018-10-26           49.3133  39.6197
# 2018-10-19           61.9405  45.6007
# 2018-10-12           77.0988  62.7196
# 2018-10-05           80.5667  77.5012
# 2018-09-28           79.6913  91.0755
# 2018-09-21           70.0125  73.1234
# 2018-09-14           68.1064  74.8751
# 2018-09-07           63.8589  62.0392
# 2018-08-31           66.0439  67.4049
# 2018-08-24           69.1284  62.1325
# 2018-08-17           74.3871  68.5944
# 2018-08-10           79.8932  76.6583
# 2018-08-03           82.3564  77.9087
# 2018-07-27           78.0601  85.1126
# ...

# %%
stoch_data = stoch_data.transpose()

# %%
slowD_df = stoch_data.drop(['SlowK'], axis = 1)

# %%
slowD_df
# Out:
#                        SlowD
# 2019-01-04 16:00:01  28.3679
# 2018-12-28           39.1494
# 2018-12-21           47.1384
# 2018-12-14           57.6549
# 2018-12-07           56.9173
# 2018-11-30           59.2271
# 2018-11-23           54.9589
# 2018-11-16           48.5661
# 2018-11-09           41.9925
# 2018-11-02           40.8159
# 2018-10-26           49.3133
# 2018-10-19           61.9405
# 2018-10-12           77.0988
# 2018-10-05           80.5667
# 2018-09-28           79.6913
# 2018-09-21           70.0125
# 2018-09-14           68.1064
# 2018-09-07           63.8589
# 2018-08-31           66.0439
# 2018-08-24           69.1284
# 2018-08-17           74.3871
# 2018-08-10           79.8932
# 2018-08-03           82.3564
# 2018-07-27           78.0601
# 2018-07-20           67.6120
# 2018-07-13           56.5032
# 2018-07-06           58.4983
# 2018-06-29           68.1283
# 2018-06-22           82.1286
# 2018-06-15           87.8309
# ...                      ...
# ...

# %%
slowK_df = stoch_data.drop(['SlowD'], axis = 1)

# %%
idx = 11

msft_df.insert(loc=idx, column='SlowD', value=slowD_df)

# %%
idx = 12

msft_df.insert(loc=idx, column='SlowK', value=slowK_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
PARAMS = {'function':'RSI', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}




rsi_response = requests.get(URL,PARAMS)

# %%
rsi_response.status_code
# Out:
# 200

# %%
rsi_response.json()
# Out:
# {'Meta Data': {'1: Symbol': 'MSFT',
#   '2: Indicator': 'Relative Strength Index (RSI)',
#   '3: Last Refreshed': '2019-01-04 16:00:01',
#   '4: Interval': 'weekly',
#   '5: Time Period': 2,
#   '6: Series Type': 'open',
#   '7: Time Zone': 'US/Eastern Time'},
#  'Technical Analysis: RSI': {'2019-01-04 16:00:01': {'RSI': '46.0989'},
#   '2018-12-28': {'RSI': '12.0706'},
#   '2018-12-21': {'RSI': '37.2440'},
#   '2018-12-14': {'RSI': '31.6169'},
#   '2018-12-07': {'RSI': '79.5729'},
#   '2018-11-30': {'RSI': '15.1292'},
#   '2018-11-23': {'RSI': '45.6555'},
#   '2018-11-16': {'RSI': '68.4885'},
#   '2018-11-09': {'RSI': '6.4398'},
#   '2018-11-02': {'RSI': '14.6380'},
#   '2018-10-26': {'RSI': '26.4101'},
#   '2018-10-19': {'RSI': '14.8569'},
#   '2018-10-12': {'RSI': '31.3770'},
#   '2018-10-05': {'RSI': '83.6081'},
#   '2018-09-28': {'RSI': '69.4582'},
#   '2018-09-21': {'RSI': '83.2451'},
#   '2018-09-14': {'RSI': '38.1039'},
#   '2018-09-07': {'RSI': '86.2631'},
# ...

# %%
rs = rsi_response.json()

# %%
rsi_data = pd.DataFrame(rs['Technical Analysis: RSI'])

# %%
rsi_data
# Out:
#     2019-01-04 16:00:01 2018-12-28 2018-12-21 2018-12-14 2018-12-07  \
# RSI             46.0989    12.0706    37.2440    31.6169    79.5729
#
#     2018-11-30 2018-11-23 2018-11-16 2018-11-09 2018-11-02    ...      \
# RSI    15.1292    45.6555    68.4885     6.4398    14.6380    ...
#
#     1998-03-27 1998-03-20 1998-03-13 1998-03-06 1998-02-27 1998-02-20  \
# RSI    10.9475    13.0208    13.0803    15.0043     4.7569    92.1329
#
#     1998-02-13 1998-02-06 1998-01-30 1998-01-23
# RSI    94.9436    91.1741    76.0130    58.9219
#
# [1 rows x 1094 columns]

# %%
rsi_data.transpose()
# Out:
#                          RSI
# 2019-01-04 16:00:01  46.0989
# 2018-12-28           12.0706
# 2018-12-21           37.2440
# 2018-12-14           31.6169
# 2018-12-07           79.5729
# 2018-11-30           15.1292
# 2018-11-23           45.6555
# 2018-11-16           68.4885
# 2018-11-09            6.4398
# 2018-11-02           14.6380
# 2018-10-26           26.4101
# 2018-10-19           14.8569
# 2018-10-12           31.3770
# 2018-10-05           83.6081
# 2018-09-28           69.4582
# 2018-09-21           83.2451
# 2018-09-14           38.1039
# 2018-09-07           86.2631
# 2018-08-31           72.7035
# 2018-08-24           39.3712
# 2018-08-17           98.4653
# 2018-08-10           97.0150
# 2018-08-03           95.0878
# 2018-07-27           92.8918
# 2018-07-20           90.8158
# 2018-07-13           76.4984
# 2018-07-06           10.9953
# 2018-06-29           43.4384
# 2018-06-22           43.7783
# 2018-06-15           93.5710
# ...                      ...
# ...

# %%
rsi_df = rsi_data.transpose()

# %%
rsi_df
# Out:
#                          RSI
# 2019-01-04 16:00:01  46.0989
# 2018-12-28           12.0706
# 2018-12-21           37.2440
# 2018-12-14           31.6169
# 2018-12-07           79.5729
# 2018-11-30           15.1292
# 2018-11-23           45.6555
# 2018-11-16           68.4885
# 2018-11-09            6.4398
# 2018-11-02           14.6380
# 2018-10-26           26.4101
# 2018-10-19           14.8569
# 2018-10-12           31.3770
# 2018-10-05           83.6081
# 2018-09-28           69.4582
# 2018-09-21           83.2451
# 2018-09-14           38.1039
# 2018-09-07           86.2631
# 2018-08-31           72.7035
# 2018-08-24           39.3712
# 2018-08-17           98.4653
# 2018-08-10           97.0150
# 2018-08-03           95.0878
# 2018-07-27           92.8918
# 2018-07-20           90.8158
# 2018-07-13           76.4984
# 2018-07-06           10.9953
# 2018-06-29           43.4384
# 2018-06-22           43.7783
# 2018-06-15           93.5710
# ...                      ...
# ...

# %%
idx = 13

msft_df.insert(loc=idx, column='RSI', value=rsi_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
PARAMS = {'function':'ADX', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}




adx_response = requests.get(URL,PARAMS)

# %%
adx_response.status_code
# Out:
# 200

# %%
adx_response.json()
# Out:
# {'Meta Data': {'1: Symbol': 'MSFT',
#   '2: Indicator': 'Average Directional Movement Index (ADX)',
#   '3: Last Refreshed': '2019-01-04 16:00:01',
#   '4: Interval': 'weekly',
#   '5: Time Period': 2,
#   '6: Time Zone': 'US/Eastern Time'},
#  'Technical Analysis: ADX': {'2019-01-04 16:00:01': {'ADX': '76.4677'},
#   '2018-12-28': {'ADX': '70.1963'},
#   '2018-12-21': {'ADX': '52.7628'},
#   '2018-12-14': {'ADX': '28.7933'},
#   '2018-12-07': {'ADX': '35.6332'},
#   '2018-11-30': {'ADX': '30.2439'},
#   '2018-11-23': {'ADX': '58.5448'},
#   '2018-11-16': {'ADX': '42.2685'},
#   '2018-11-09': {'ADX': '55.2591'},
#   '2018-11-02': {'ADX': '93.6373'},
#   '2018-10-26': {'ADX': '89.1244'},
#   '2018-10-19': {'ADX': '80.8518'},
#   '2018-10-12': {'ADX': '71.5883'},
#   '2018-10-05': {'ADX': '53.0613'},
#   '2018-09-28': {'ADX': '68.2194'},
#   '2018-09-21': {'ADX': '60.5615'},
#   '2018-09-14': {'ADX': '45.2456'},
#   '2018-09-07': {'ADX': '34.5909'},
# ...

# %%
ad = adx_response.json()

# %%
adx_data = pd.DataFrame(ad['Technical Analysis: ADX'])

# %%
adx_data.transpose()
# Out:
#                           ADX
# 2019-01-04 16:00:01   76.4677
# 2018-12-28            70.1963
# 2018-12-21            52.7628
# 2018-12-14            28.7933
# 2018-12-07            35.6332
# 2018-11-30            30.2439
# 2018-11-23            58.5448
# 2018-11-16            42.2685
# 2018-11-09            55.2591
# 2018-11-02            93.6373
# 2018-10-26            89.1244
# 2018-10-19            80.8518
# 2018-10-12            71.5883
# 2018-10-05            53.0613
# 2018-09-28            68.2194
# 2018-09-21            60.5615
# 2018-09-14            45.2456
# 2018-09-07            34.5909
# 2018-08-31            52.5675
# 2018-08-24            33.3384
# 2018-08-17            38.7752
# 2018-08-10            60.9974
# 2018-08-03            56.8114
# 2018-07-27            82.8326
# 2018-07-20            71.3574
# 2018-07-13            54.6447
# 2018-07-06            32.3609
# 2018-06-29            56.6143
# 2018-06-22            39.1495
# 2018-06-15            74.9336
# ...

# %%
adx_df= adx_data.transpose()

# %%
idx = 14

msft_df.insert(loc=idx, column='ADX', value=adx_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
PARAMS = {'function':'CCI', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}




cci_response = requests.get(URL,PARAMS)

# %%
cci_response.status_code
# Out:
# 200

# %%
cc = cci_response.json()

# %%
cc_data = pd.DataFrame(cc['Technical Analysis: CCI'])

# %%
cci_df = cc_data.transpose()

# %%
cci_df
# Out:
#                           CCI
# 2019-01-04 16:00:01   66.6667
# 2018-12-28           -66.6667
# 2018-12-21           -66.6667
# 2018-12-14           -66.6667
# 2018-12-07           -66.6667
# 2018-11-30            66.6667
# 2018-11-23           -66.6667
# 2018-11-16           -66.6667
# 2018-11-09            66.6667
# 2018-11-02           -66.6667
# 2018-10-26           -66.6667
# 2018-10-19            66.6667
# 2018-10-12           -66.6667
# 2018-10-05           -66.6667
# 2018-09-28            66.6667
# 2018-09-21            66.6667
# 2018-09-14            66.6667
# 2018-09-07           -66.6667
# 2018-08-31            66.6667
# 2018-08-24           -66.6667
# 2018-08-17           -66.6667
# 2018-08-10            66.6667
# 2018-08-03           -66.6667
# 2018-07-27            66.6667
# 2018-07-20            66.6667
# 2018-07-13            66.6667
# 2018-07-06            66.6667
# 2018-06-29           -66.6667
# 2018-06-22            66.6667
# 2018-06-15           -66.6667
# ...

# %%
idx = 15

msft_df.insert(loc=idx, column='CCI', value=cci_df)

# %%
PARAMS = {'function':'AROON', 'symbol':'MSFT', 'interval': 'weekly','time_period': 2, 'series_type':'open','datatype':'json', 'apikey':'ZW3O2KDPKU9A9HH8'}




aroon_response = requests.get(URL,PARAMS)

# %%
aroon_response.status_code
# Out:
# 200

# %%
ar = aroon_response.json()

# %%
aroon_data = pd.DataFrame(ar['Technical Analysis: AROON'])

# %%
aroon_df = aroon_data.transpose()

# %%
aroon_df
# Out:
#                     Aroon Down  Aroon Up
# 2019-01-04 16:00:01    50.0000    0.0000
# 2018-12-28            100.0000    0.0000
# 2018-12-21            100.0000    0.0000
# 2018-12-14            100.0000   50.0000
# 2018-12-07              0.0000  100.0000
# 2018-11-30             50.0000  100.0000
# 2018-11-23            100.0000    0.0000
# 2018-11-16              0.0000   50.0000
# 2018-11-09             50.0000  100.0000
# 2018-11-02            100.0000    0.0000
# 2018-10-26            100.0000    0.0000
# 2018-10-19             50.0000    0.0000
# 2018-10-12            100.0000   50.0000
# 2018-10-05            100.0000  100.0000
# 2018-09-28              0.0000   50.0000
# 2018-09-21              0.0000  100.0000
# 2018-09-14             50.0000  100.0000
# 2018-09-07              0.0000   50.0000
# 2018-08-31             50.0000  100.0000
# 2018-08-24            100.0000    0.0000
# 2018-08-17              0.0000   50.0000
# 2018-08-10             50.0000    0.0000
# ...

# %%
aroon_down_df = aroon_df.drop(['Aroon Up'], axis = 1)

# %%
aroon_up_df = aroon_df.drop(['Aroon Down'], axis = 1)

# %%
idx = 16

msft_df.insert(loc=idx, column='Aroon Down', value=aroon_down_df)

# %%
idx = 17

msft_df.insert(loc=idx, column='Aroon Up', value=aroon_up_df)

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
msft_df['MACD'][1060:1063]
# Out:
# 1998-09-11    -1.7628
# 1998-09-04    -1.5430
# 1998-08-28    -1.7358
# Name: MACD, dtype: object

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
msft_df = msft_df.drop(msft_df.index[1063:])

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
msft_df['MACD'][0] = 0.2448

# %%
msft_df['MACD_Hist'][0] = -1.6971

# %%
msft_df['MACD_Signal'][0] = 1.9419

# %%
msft_df['SlowD'][0] = 25.7814

# %%
msft_df['SlowK'][0] = 18.5147

# %%
msft_df['RSI'][0] = 46.0989

# %%
msft_df['ADX'][0] = 78.9130

# %%
msft_df['Aroon Down'][0] = 50.000

# %%
msft_df['Aroon Up'][0] = 0

# %%
msft_df['CCI'][0] = 66.6667

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
msft_df
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2019-01-04   MSFT  101.2900  102.5100   97.2000  102.2350  135850094
# 2018-12-28   MSFT   97.6800  102.4100   93.9600  100.3900  183237806
# 2018-12-21   MSFT  105.4100  106.8800   97.4600   98.2300  356050950
# 2018-12-14   MSFT  104.8000  111.2700  103.8900  106.0300  197742990
# 2018-12-07   MSFT  113.0000  113.4200  104.3000  104.8200  174082124
# 2018-11-30   MSFT  104.7900  111.3300  104.5800  110.8900  170037931
# 2018-11-23   MSFT  108.2700  108.5600   99.3528  103.0700  150780076
# 2018-11-16   MSFT  109.4200  109.9600  103.9100  108.2900  180498817
# 2018-11-09   MSFT  106.3700  112.2400  105.9000  109.5700  147847424
# 2018-11-02   MSFT  108.1050  108.7000  100.1100  106.1600  242639657
# 2018-10-26   MSFT  109.3200  110.5400  101.5901  106.9600  251383718
# 2018-10-19   MSFT  108.9100  111.8100  106.9468  108.6600  155518177
# 2018-10-12   MSFT  111.6600  113.0800  104.2000  109.5700  228861873
# ...

# %%
msft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1063 entries, 2019-01-04 to 1998-08-28
# Data columns (total 18 columns):
# Entity         1063 non-null object
# 1. open        1063 non-null object
# 2. high        1063 non-null object
# 3. low         1063 non-null object
# 4. close       1063 non-null object
# 5. volume      1063 non-null object
# SMA            1063 non-null object
# EMA            1063 non-null object
# MACD           1063 non-null object
# MACD_Hist      1063 non-null object
# MACD_Signal    1063 non-null object
# SlowD          1063 non-null object
# SlowK          1063 non-null object
# RSI            1063 non-null object
# ADX            1063 non-null object
# CCI            1063 non-null object
# Aroon Down     1063 non-null object
# Aroon Up       1063 non-null object
# dtypes: object(18)
# memory usage: 197.8+ KB

# %%
msft_df.describe()
# Out:
#        Entity  1. open  2. high   3. low 4. close  5. volume      SMA  \
# count    1063     1063     1063     1063     1063       1063     1063
# unique      1      916      909      916      934       1062      985
# top      MSFT  25.2400  27.5000  26.1000  28.0200  374068400  27.1000
# freq     1063        5        6        5        4          2        4
#
#             EMA     MACD MACD_Hist MACD_Signal    SlowD    SlowK      RSI  \
# count      1063     1063      1063        1063     1063     1063     1063
# unique     1058     1057      1025        1050     1063     1063     1057
# top     28.6207  -0.2899    0.3006      0.2991  93.4278  14.7799  76.8811
# freq          2        2         2           2        1        1        3
#
#             ADX      CCI Aroon Down  Aroon Up
# count      1063     1063       1063      1063
# unique     1063        4          4         4
# top     78.3874  66.6667     0.0000  100.0000
# freq          1      564        464       456

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(msft_df, test_size = 0.2, random_state = 42)

# %%
msft = train_set.copy()

# %%
msft
# Out:
#            Entity   1. open   2. high    3. low  4. close  5. volume  \
# 2017-08-18   MSFT   73.0600   74.1000   71.9300   72.4900   95411795
# 2001-09-28   MSFT   50.6500   53.0000   48.0000   51.1700  213438800
# 2018-03-02   MSFT   94.4000   95.8400   90.8600   93.0500  154581506
# 2013-02-01   MSFT   28.0100   28.2250   27.4000   27.9300  254975500
# 2003-12-05   MSFT   25.9000   26.4800   25.5000   25.9800  463971200
# 2012-08-31   MSFT   30.9300   30.9600   30.2200   30.8200  142558000
# 2012-04-13   MSFT   31.2200   31.4000   30.2300   30.8100  206254900
# 2011-12-23   MSFT   26.0200   26.1900   25.4400   26.0300  236158300
# 2011-10-14   MSFT   26.5800   27.5000   26.4700   27.2700  227902500
# 2000-02-04   MSFT   97.6200  108.0000   94.8700  106.5600  148928900
# 2013-02-08   MSFT   27.8700   28.0200   27.1000   27.5500  199186800
# 2010-08-06   MSFT   25.9900   26.3800   25.0200   25.5500  311358400
# 2005-04-29   MSFT   25.0700   25.3000   24.4400   25.3000  365919300
# ...

# %%
import seaborn as sns

# %%
a = np.linspace(0,849,850)

plt.scatter(x=a, y=msft['1. open'][1:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-249-a3fe67e97e19> in <module>()
#       1 a = np.linspace(0,849,850)
#       2
# ----> 3 plt.scatter(x=a, y=msft['1. open'][1:])
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3473                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3474                          linewidths=linewidths, verts=verts,
# -> 3475                          edgecolors=edgecolors, data=data, **kwargs)
#    3476     finally:
#    3477         ax._hold = washold
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
corr_matrix = msft.iloc[:,1:].corr()

# %%
corr_matrix
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
msft.dtypes
# Out:
# Entity         object
# 1. open        object
# 2. high        object
# 3. low         object
# 4. close       object
# 5. volume      object
# SMA            object
# EMA            object
# MACD           object
# MACD_Hist      object
# MACD_Signal    object
# SlowD          object
# SlowK          object
# RSI            object
# ADX            object
# CCI            object
# Aroon Down     object
# Aroon Up       object
# dtype: object

# %%
msft = msft.drop(['Entity'],axis=1)

# %%
msft = msft.astype(float)

# %%
corr_matrix = msft.corr()

# %%
corr_matrix
# Out:
#               1. open   2. high    3. low  4. close  5. volume       SMA  \
# 1. open      1.000000  0.997940  0.998011  0.995970  -0.580074  0.998855
# 2. high      0.997940  1.000000  0.997261  0.998401  -0.569501  0.997192
# 3. low       0.998011  0.997261  1.000000  0.997812  -0.593188  0.996921
# 4. close     0.995970  0.998401  0.997812  1.000000  -0.581061  0.994942
# 5. volume   -0.580074 -0.569501 -0.593188 -0.581061   1.000000 -0.578698
# SMA          0.998855  0.997192  0.996921  0.994942  -0.578698  1.000000
# EMA          0.999372  0.997589  0.997337  0.995388  -0.579305  0.999741
# MACD         0.273131  0.261566  0.281631  0.268725  -0.156312  0.271514
# MACD_Hist    0.160536  0.160472  0.164703  0.161436  -0.070474  0.152962
# MACD_Signal  0.231704  0.218781  0.239297  0.226353  -0.142494  0.233393
# SlowD        0.174777  0.168537  0.184265  0.178402  -0.223450  0.166118
# SlowK        0.163706  0.163290  0.178097  0.179529  -0.238626  0.149373
# ...

# %%
msft.dtypes
# Out:
# 1. open        float64
# 2. high        float64
# 3. low         float64
# 4. close       float64
# 5. volume      float64
# SMA            float64
# EMA            float64
# MACD           float64
# MACD_Hist      float64
# MACD_Signal    float64
# SlowD          float64
# SlowK          float64
# RSI            float64
# ADX            float64
# CCI            float64
# Aroon Down     float64
# Aroon Up       float64
# dtype: object

# %%
corr_matrix['1. open'].sort_values(ascending=False)
# Out:
# 1. open        1.000000
# EMA            0.999372
# SMA            0.998855
# 3. low         0.998011
# 2. high        0.997940
# 4. close       0.995970
# MACD           0.273131
# MACD_Signal    0.231704
# SlowD          0.174777
# SlowK          0.163706
# MACD_Hist      0.160536
# RSI            0.123898
# Aroon Up       0.083296
# CCI            0.046489
# ADX           -0.025625
# Aroon Down    -0.074259
# 5. volume     -0.580074
# Name: 1. open, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ['1. open', 'EMA', 'SMA', '3. low', 'MACD']
scatter_matrix(msft[attributes], figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ab22cc0>,
# ...
#       dtype=object)
